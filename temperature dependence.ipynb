# %%
def calc_vn(V0, G1, G2):
    return 10 * V0 / ((G1 * G2)**2)
vn = calc_vn(0.0503, 600, 1500)
print(vn)
def calc_kb(V,R,T,F):
    return ( V) / (4* R * T* F)

def calc_vj(V, G1, G2):
    return ((10*V) / ((G1 * G2)**2)) - vn
# Out:
# 6.209876543209877e-13

# %%
## CONSTANTS
CONST_G1 = 600
CONST_G2 = 1500
CONST_R = 10000
CONST_VOUT = .08735
CONST_DELTA_F = 9957.4 # THIS IS FOR .1 TO 100KHZ
CONST_TEMP = 77 #ROOM TEMP MEASURED ABOVE HLE

# %%
kb = calc_kb( calc_vj(CONST_VOUT,CONST_G1,CONST_G2 ), CONST_R, CONST_TEMP, CONST_DELTA_F )
print(kb)
# Out:
# 1.4914425302679264e-23

# %%
## CORRECT VALUE IS 1.38

# %% [markdown]
# # BEGIN SCRIPT

# %%
import pandas as pd

# %%
df = pd.read_csv("temperature.csv")

# %%
df["temperature"] = (1000* df["calibration"] - 1221) / -2.68
df["output"] = df["output"] / 1000
df
# Out:
#     calibration   output  temperature
# 0         0.989  0.08760    86.567164
# 1         0.989  0.08753    86.567164
# 2         0.989  0.08732    86.567164
# 3         0.989  0.08720    86.567164
# 4         0.989  0.08755    86.567164
# 5         0.989  0.08725    86.567164
# 6         0.989  0.08705    86.567164
# 7         0.989  0.08785    86.567164
# 8         0.989  0.08715    86.567164
# 9         0.989  0.08725    86.567164
# 10        0.989  0.08756    86.567164
# 11        0.989  0.08735    86.567164
# 12        0.974  0.09354    92.164179
# 13        0.964  0.09332    95.895522
# 14        0.959  0.09336    97.761194
# 15        0.957  0.09300    98.507463
# 16        0.955  0.09387    99.253731
# 17        0.953  0.09506   100.000000
# 18        0.952  0.09490   100.373134
# 19        0.947  0.09526   102.238806
# 20        0.944  0.09513   103.358209
# 21        0.942  0.09560   104.104478
# 22        0.938  0.09687   105.597015
# 23        0.936  0.09802   106.343284
# 24        0.930  0.09875   108.582090
# 25        0.924  0.09931   110.820896
# 26        0.915  0.10142   114.179104
# 27        0.912  0.10209   115.298507
# 28        0.908  0.10294   116.791045
# 29        0.904  0.10439   118.283582
# 30        0.895  0.10589   121.641791
# 31        0.885  0.10880   125.373134
# 32        0.875  0.10950   129.104478
# 33        0.859  0.11210   135.074627
# 34        0.851  0.11386   138.059701
# 35        0.745  0.12727   177.611940
# 36        0.730  0.13000   183.208955
# 37        0.710  0.13287   190.671642
# 38        0.694  0.13741   196.641791
# 39        0.673  0.14022   204.477612
# 40        0.662  0.14362   208.582090
# 41        0.621  0.14972   223.880597
# 42        0.585  0.15627   237.313433
# 43        0.566  0.15989   244.402985

# %%
df["kb"] = calc_kb( calc_vj(df["output"],CONST_G1,CONST_G2 ), CONST_R, df["temperature"], CONST_DELTA_F )

# %%
df["kb"]
# Out:
# 0     1.335564e-23
# 1     1.333057e-23
# 2     1.325538e-23
# 3     1.321242e-23
# 4     1.333774e-23
# 5     1.323032e-23
# 6     1.315871e-23
# 7     1.344515e-23
# 8     1.319451e-23
# 9     1.323032e-23
# 10    1.334132e-23
# 11    1.326612e-23
# 12    1.454228e-23
# 13    1.390532e-23
